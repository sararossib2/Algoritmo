# %% [markdown]
# <a href="https://colab.research.google.com/github/sararossib2/Algoritmo/blob/main/Aula3_match_case.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **🎯 Aula: Estrutura match case em Python**
#
# # **1. Introdução ao match case**
#
# O match case foi introduzido no **Python 3.10** como uma forma mais elegante de lidar com múltiplas condições, substituindo estruturas complexas de if-elif-else.
#
# Ele é inspirado no switch case de outras linguagens, mas com mais recursos, como correspondência de padrões e desestruturação de dados.
#
# **✅ Principais vantagens do match case:**
#
# * Código mais legível e organizado.
# * Permite correspondência de padrões, não apenas valores diretos.
# * Suporte para tuplas, listas, dicionários e classes.

# %% [markdown]
# # **2. Estrutura básica do match case**
#
# A sintaxe do match case segue este formato:

# %%
match expressão:
    case padrão1:
        # Código executado se expressão corresponder ao padrão1
    case padrão2:
        # Código executado se expressão corresponder ao padrão2
    case _:
        # Caso padrão (equivalente ao "default" do switch case)

# %% [markdown]
# **Exemplo 1: Correspondência de valores exatos**
#
# Este é o caso mais simples, onde o match case é utilizado para corresponder valores exatos, como uma correspondência de um valor específico.

# %%
dia = input("Digite o dia da semana: ")

match dia:
  case "segunda":
    print("Início da semana")
  case "terça":
    print("Dia de trabalho")
  case "quarta":
    print("Meio da semana")
  case "quinta":
    print("Quase lá!")
  case "sexta":
    print("Sextou!")
  case "sábado" | "domingo":
    print("Final de semana")
  case _:
    print("Dia inválido")
# Out:
# Digite o dia da semana: ola
# Dia inválido

# %% [markdown]
# **🛠 Explicação:**
#
# * O match case compara a variável dia com os valores que você define nos case. Cada valor pode ser um valor exato (como "segunda", "terça", etc.).
# * A linha case "sábado" | "domingo": usa o operador | para combinar múltiplos valores no mesmo caso, funcionando como um or.
# * O case _ é o coringa que será usado quando nenhum dos valores anteriores for encontrado.

# %% [markdown]
# **Exemplo 2: Identificação de Tipos de Produto**

# %%
codigo = input("Digite o código do produto: ")

match codigo:
    case "A001":
        print("Produto eletrônico")
    case "B002":
        print("Produto alimentício")
    case "C003":
        print("Produto de vestuário")
    case "D004":
        print("Produto de limpeza")
    case _:
        print("Código inválido")
# Out:
# Digite o código do produto: C003
# Produto de vestuário

# %% [markdown]
# **Explicação:**
# * O código solicita que o usuário insira um código de produto.
#
# * Utiliza o match case para identificar e imprimir o tipo do produto correspondente ao código inserido.

# %% [markdown]
# **Exemplo 3: Classificação de um Animal por Tipo**
#
# Neste exemplo, vamos classificar o tipo de animal com base na entrada do usuário.

# %%
animal = input("Digite o nome de um animal: ").lower()

match animal:
    case "cachorro" | "gato" | "coelho":
        print("Mamífero")
    case "pássaro" | "peru" | "canário":
        print("Ave")
    case "crocodilo" | "lagarto" | "iguana":
        print("Réptil")
    case "tubarão" | "salmão" | "sardinha":
        print("Peixe")
    case _:
        print("Animal desconhecido")

# %% [markdown]
# # **3. Criando Menus Interativos com match case**
#
# Quando usado em um menu interativo, o match case torna o código mais intuitivo, permitindo que o programador mapeie facilmente as opções de um menu a ações específicas.

# %% [markdown]
# **Exemplo 1: Menu de opções simples**
#
# Vamos criar um menu simples onde o usuário pode escolher uma opção, e o programa executa uma ação com base na escolha.

# %%
# Menu interativo utilizando match case
opcao = int(input("Escolha uma opção: \n1. Exibir mensagem\n2. Calcular soma\n3. Sair\n"))

match opcao:
    case 1:
        print("Você escolheu 'Exibir mensagem'. Olá, bem-vindo ao menu!")
    case 2:
        numero1 = int(input("Digite o primeiro número: "))
        numero2 = int(input("Digite o segundo número: "))
        print(f"A soma é: {numero1 + numero2}")
    case 3:
        print("Saindo do programa. Até logo!")
    case _:
        print("Opção inválida! Tente novamente.")

# %% [markdown]
# **Explicação:**
#
# * **`input()`**: O programa solicita ao usuário uma entrada, que é convertida para um número inteiro (por isso a função int()).
# * **`match opcao:`** A variável opcao será comparada com os padrões definidos nos case.
# * **`case 1, case 2, case 3`**: Cada opção do menu mapeia para uma ação específica.
# * **`case _:`** Esse coringa garante que qualquer valor fora das opções válidas será tratado com uma mensagem de erro.

# %% [markdown]
# **Exemplo 2: Menu com operação de multiplicação**
#
# Neste exemplo, vamos criar um menu que permite ao usuário escolher entre realizar uma multiplicação ou sair do programa.

# %%
# Menu interativo para multiplicação
opcao = int(input("Escolha uma opção: \n1. Multiplicar números\n2. Sair\n"))

match opcao:
    case 1:
        numero1 = int(input("Digite o primeiro número: "))
        numero2 = int(input("Digite o segundo número: "))
        print(f"O resultado da multiplicação é: {numero1 * numero2}")
    case 2:
        print("Saindo do programa.")
    case _:
        print("Opção inválida! Por favor, escolha uma opção válida.")

# %% [markdown]
# **Explicação:**
# * O menu tem duas opções: multiplicar números ou sair.
# * Se o usuário escolher a opção 1, o programa pedirá dois números e fará a multiplicação.
# * Se o usuário escolher a opção 2, o programa sairá.

# %% [markdown]
# **Exempo 3. Caixa Eletrônico com um menu utilizando match case, onde o usuário pode consultar saldo, sacar, depositar ou sair**

# %%
saldo = 1000  # Saldo inicial da conta

while True:
    print("\n===== CAIXA ELETRÔNICO =====")
    print("1 - Saldo")
    print("2 - Saque")
    print("3 - Depósito")
    print("4 - Sair")

    opcao = input("Escolha uma opção: ")

    match opcao:
        case "1":
            print(f"Seu saldo atual é R$ {saldo:.2f}")

        case "2":
            valor = float(input("Digite o valor para saque: "))
            if valor > saldo:
                print("Saldo insuficiente!")
            else:
                saldo -= valor
                print(f"Saque de R$ {valor:.2f} realizado. Novo saldo: R$ {saldo:.2f}")

        case "3":
            valor = float(input("Digite o valor para depósito: "))
            saldo += valor
            print(f"Depósito de R$ {valor:.2f} realizado. Novo saldo: R$ {saldo:.2f}")

        case "4":
            print("Saindo... Obrigado por utilizar nosso caixa eletrônico!")
            break

        case _:
            print("Opção inválida. Escolha uma opção válida.")

# %% [markdown]
# **Considerações sobre o uso do match case em menus**
#
# * **Legibilidade**: O match case torna o código mais legível em comparação com o uso de múltiplos if-elif-else. Isso é especialmente útil quando você tem várias opções no menu.
# * **Facilidade de manutenção**: Se você precisar adicionar mais opções no menu, basta adicionar novos case com a lógica correspondente.
# * **Coringa (_)**: O case _ ajuda a capturar qualquer valor não mapeado, garantindo que entradas inválidas sejam tratadas de maneira adequada.

# %% [markdown]
# ## **1. Conversor de Moedas (Solução)**

# %%
taxa_dolar = 4.95
taxa_euro = 5.35
taxa_libra = 6.15

print("\n--- Conversor de Moedas ---")
print("Escolha a moeda para converter para Reais (BRL):")
print("1. Dólar Americano (USD)")
print("2. Euro (EUR)")
print("3. Libra Esterlina (GBP)")

opcao_moeda = input("Digite o número da sua escolha (1, 2 ou 3): ")

if opcao_moeda in ['1', '2', '3']:
    try:
        valor_entrada = float(input("Digite o valor a ser convertido: "))

        match opcao_moeda:
            case '1':
                valor_convertido = valor_entrada * taxa_dolar
                print(f"{valor_entrada:.2f} USD equivalem a {valor_convertido:.2f} BRL")
            case '2':
                valor_convertido = valor_entrada * taxa_euro
                print(f"{valor_entrada:.2f} EUR equivalem a {valor_convertido:.2f} BRL")
            case '3':
                valor_convertido = valor_entrada * taxa_libra
                print(f"{valor_entrada:.2f} GBP equivalem a {valor_convertido:.2f} BRL")
    except ValueError:
        print("Entrada inválida. Por favor, digite um número para o valor.")
else:
    print("Opção de moeda inválida. Por favor, escolha 1, 2 ou 3.")
# Out:
# --- Conversor de Moedas ---
# Escolha a moeda para converter para Reais (BRL):
# 1. Dólar Americano (USD)
# 2. Euro (EUR)
# 3. Libra Esterlina (GBP)
# Digite o número da sua escolha (1, 2 ou 3): 3
# Digite o valor a ser convertido: 700
# 700.00 GBP equivalem a 4305.00 BRL

# %%
print("\n--- Cáculo de Aréa ---")
print("Escolha a opção para realizar o cálculo:")
print("1. Quadrado")
print("2. Triângulo")
print("3. Retângulo")

opcao_area= input("Digite o número da sua escolha (1, 2, 3)")
if opcao_area in ["1"]:
    try:
        valor_entrada = float(input("Digite o valor do lado do quadrado:"))
        match opcao_area:
          case"1":
            area_quadrado= valor_entrada* valor_entrada
            print(f"A área do quadrado é {area_quadrado:.2f}")
          case"2":
            base=float (input("Digite o valor da base do trãngulo:"))
            altura=float(input("Digite o valor da altura do triângulo:"))
            area_triangulo=(base*altura)/2
            print(f"A área do triângulo é {area_triangulo :.2f}")
          case"3":
            base=float(input("Digite o valor da base do retângulo:"))
            altura=float(input("Digite o valor da altura do retângulo:"))
            area_retangulo=base*altura
            print(f"A área do retângulo é {area_retangulo :.2f}")
    except ValueError:
      print("Entrada inválida. Por valor, digite um valor:")
else:
    print("Opção inválida. Por Favor, escolha 1, 2 ou 3.")
# Out:
# --- Cáculo de Aréa ---
# Escolha a opção para realizar o cálculo:
# 1. Quadrado
# 2. Triângulo
# 3. Retângulo
# Digite o número da sua escolha (1, 2, 3)1
# Digite o valor do lado do quadrado:5
# A área do quadrado é 25.00

# %%
print("\n--- Sistema de Login---")
nome_usuario = input("Digite seu nome: ").lower()

match nome_usuario:
    case "admin":
        print("Acesso total concedido.")
    case "professor":
        print("Acesso em ambiente de estudos concedido.")
    case "aluno":
        print("Acesso em ambiente de estudo concedido.")
    case _:
        print("Nome de usuário não reconhecido. Acesso negado.")
# Out:
# --- Sistema de Login---
# Digite seu nome: Sara
# Nome de usuário não reconhecido. Acesso negado.

# %%
produto = input("Digite o tipo de produto: ").lower()

match produto:
    case "eletrônico":
        print("Você comprou um produto eletrônico. Seu percentual de desconto é de 10%")
    case "roupas":
        print("Você comprou roupas. Seu percentual de desconto é de 5%")
    case "alimentos":
        print("Você comprou alimentos. Seu percentual de desconto é de 2%")
    case "móveis":
        print("Você comprou móveis. Seu percentual de desconto é de 25%")
    case _:
        print("Produto desconhecido")
# Out:
# Digite o tipo de produto: eletrônico
# Você comprou um produto eletrônico. Seu percentual de desconto é de 10%

# %%
print("\n--- Cor ---")
print("Selecione uma cor em português:")
print("1. Vermelho")
print("2. Azul")
print("3. Verde")
print("4. Amarelo")

opcao_cor = input("Digite o número da sua escolha (1, 2, 3 ou 4): ")

match opcao_cor:
    case "1":
      opcao_cor= "red"
      print("Você escolheu a cor vermelha. Em inglês ela é escrita como RED")
    case "2":
      opcao_cor= "blue"
      print("Você escolheu a cor Azul. Em inglês ela é escrita como BLUE")
    case "3":
      opcao_cor= "green"
      print("Você escolheu a cor Verde. Em inglês ela é escrita como GREEN")
    case "4":
      opcao_cor= "yellow"
      print("Você escolheu a cor Amarelo. Em inglês ela é escrita como YELLOW")
    case _:
        print("Opção de cor inválida. Por favor, escolha 1, 2, 3 ou 4.")
# Out:
# --- Cor ---
# Selecione uma cor em português:
# 1. Vermelho
# 2. Azul
# 3. Verde
# 4. Amarelo
# Digite o número da sua escolha (1, 2, 3 ou 4): 2
# Você escolheu a cor Azul. Em inglês ela é escrita como BLUE

# %%
print("\n---- Sistema de Atendimento Telefônico ----")
print("Escolha uma opção de atendimento:")
print("1. Suporte Técnico")
print("2. Financeiro")
print("3. Cancelamento")
print("4. Falar com um atendente")
print("5. Sair")

opcao_atendimento = input("Digite o número da sua escolha (1, 2, 3, 4 ou 5): ")

match opcao_atendimento:
    case "1":
        print ("Você selecionou Suporte Técnico.")
    case "2":
        print ("Você selecionou Financeiro.")
    case "3":
        print ("Você selecionou Cancelamento.")
    case "4":
        print ("Você selecionou Falar com um atendente.")
    case "5":
        print ("Saindo do sistema.")
    case _:
        print("Opção de atendimento inválida. Por favor, escolha")
# Out:
# ---- Sistema de Atendimento Telefônico ----
# Escolha uma opção de atendimento:
# 1. Suporte Técnico
# 2. Financeiro
# 3. Cancelamento
# 4. Falar com um atendente
# 5. Sair
# Digite o número da sua escolha (1, 2, 3, 4 ou 5): 4
# Você selecionou Falar com um atendente.

# %%
print("\n--- Calculadora Simples ---")
print("Escolha uma operação matemática:")
print("1. Adição (+)")
print("2. Subtração (-)")
print("3. Multiplicação (*)")
print("4. Divisão (/)")

opcao_operacao = input("Digite o número da sua escolha (1, 2, 3 ou 4): ")
num1= float(input("Digite o primeiro número:"))
num2= float(input("Digite o segundo número:"))

match opcao_operacao:
    case "1":
        resultado = num1 + num2
        print(f"O resultado da adição é: {resultado}")
    case "2":
        resultado = num1 - num2
        print(f"O resultado da subtração é: {resultado}")
    case "3":
        resultado = num1 * num2
        print(f"O resultado da multiplicação é: {resultado}")
    case "4":
        if num2 != 0:
            resultado = num1 / num2
            print(f"O resultado da divisão é: {resultado}")
        else:
            print("Erro: Divisão por zero não é permitida.")
    case _:
           print("Opção de operação inválida. Por favor, escolha 1, 2, 3 ou 4.")
# Out:
# --- Calculadora Simples ---
# Escolha uma operação matemática:
# 1. Adição (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# Digite o número da sua escolha (1, 2, 3 ou 4): 4
# Digite o primeiro número:8
# Digite o segundo número:2
# O resultado da divisão é: 4.0

# %% [markdown]
# **6. Simulação de Atendimento Telefônico**
#
# O usuário seleciona uma opção de atendimento telefônico:
#
# 1 - Suporte Técnico
#
# 2 - Financeiro
#
# 3 - Cancelamento
#
# 4 - Falar com um atendente
#
# **7. Calculadora Simples**
#
# O usuário escolhe uma operação matemática (+, -, *, /) e insere dois números. O programa exibe o resultado.
#
# **8. Sistema de Reserva de Passagens**
#
# O usuário escolhe um destino (São Paulo, Rio de Janeiro, Curitiba, Salvador) e recebe o valor da passagem.
#
# **9. Simulador de Compra em Loja Online**
#
# O usuário escolhe um produto e o programa informa o preço.
#
# **10. Sistema de Pagamento**
#
# O usuário escolhe uma forma de pagamento e o programa informa se há desconto ou acréscimo.

# %%
print("\n--- Sistema de Reserva de Passagens ---")
print("Escolha um destino:")
print("1. São Paulo")
print("2. Rio de Janeiro")
print("3. Curitiba")
print("4. Salvador")

opcao_destino = input("Digite o número do seu destino (1, 2, 3 ou 4): ")

match opcao_destino:
    case "1":
        print("Você selecionou São Paulo. O valor da passagem é R$ 50,00")
    case "2":
        print("Você selecionou Rio de Janeiro. O valor da passagem é R$ 100,00")
    case "3":
        print("Você selecionou Curitiba. O valor da passagem é R$ 70,00")
    case "4":
        print("Você selecionou Salvador. O valor da passagem é R$ 60,00")
    case _:
        print("Destino inválido. Por favor, escolha 1, 2, 3 ou 4.")
# Out:
# --- Sistema de Reserva de Passagens ---
# Escolha um destino:
# 1. São Paulo
# 2. Rio de Janeiro
# 3. Curitiba
# 4. Salvador
# Digite o número do seu destino (1, 2, 3 ou 4): 3
# Você selecionou Curitiba. O valor da passagem é R$ 70,00

# %%
print("\n----Simulador de Compra Online---")
print("Escolha um produto:")
print("1. Camiseta")
print("2. Calça")
print("3. Meia")
print("4. Boné")

opcao_produto = input("Digite um produto (1, 2 , 3 ou 4)")

match opcao_produto:
    case "1":
        print("Você selecionou camiseta. O valor é R$ 50,00")
    case "2":
        print("Você selecionou calça. O valor é R$ 100,00")
    case "3":
        print("Você selecionou meia. O valor é R$ 30,00")
    case "4":
        print("Você selecionou boné. O valor é R$ 20,00")
    case _:
        print("Produto inválido. Por favor, escolha 1, 2, 3 ou 4.")
# Out:
# ----Simulador de Compra Online---
# Escolha um produto:
# 1. Camiseta
# 2. Calça
# 3. Meia
# 4. Boné
# Digite um produto (1, 2 , 3 ou 4)1
# Você selecionou camiseta. O valor é R$ 50,00

# %%
print("\n---Sistema de Pagamento---")
print("Escolha uma forma de pagamento:")
print("1. Cartão de Crédito")
print("2. Cartão de Débito")
print("3. Dinheiro")
print("4. Pix")

opcao_pagamento = input("Digite o número da sua escolha (1, 2, 3 ou 4): ")

match opcao_pagamento:
    case "1":
        print("Você selecionou cartão de crédito. Haverá um acrescimo de R$ 02,00")
    case "2":
        print("Você selecionou cartão de débito. Haverá um desconto de R$ 03,00")
    case "3":
        print("Você selecionou dinheiro.")
    case "4":
        print("Você selecionou pix. Haverá um desconto de R$ 01,00")
# Out:
# ---Sistema de Pagamento---
# Escolha uma forma de pagamento:
# 1. Cartão de Crédito
# 2. Cartão de Débito
# 3. Dinheiro
# 4. Pix
# Digite o número da sua escolha (1, 2, 3 ou 4): 1
# Você selecionou cartão de crédito. Haverá um acrescimo de R$ 02,00
